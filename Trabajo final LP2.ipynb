# %%
#Importando paquetes
import requests
from bs4 import BeautifulSoup
from requests.adapters import HTTPAdapter
import urllib.request, urllib.parse, urllib.error
from requests.packages.urllib3.util.retry import Retry
import pandas as pd

# %% [markdown]
# # **1. WEB SCRAPING SENAHMI**

# %% [markdown]
# El SENAHMI (Servicio Nacional de Meteorología e Hidrología del Perú) es la entidad encargada de proporcionar información meteorológica y climatológica en el Perú. El web scraping, una técnica que implica la extracción automatizada de datos de páginas web, se utilizará para recopilar y organizar esta valiosa información de manera eficiente. El enfoque se centrará en respetar los términos de servicio del sitio, analizar la estructura HTML para identificar los elementos relevantes y utilizar herramientas de web scraping. Este proceso permitirá obtener datos actualizados de la SENAHMI, facilitando su posterior análisis y aplicación en diversas áreas.

# %%
# Ingresar URL
url = 'https://www.senamhi.gob.pe/?p=pronostico-meteorologico'

# Leer el contenido HTML de la URL
html = urllib.request.urlopen(url).read()

# Crear un objeto BeautifulSoup para analizar el HTML
soup = BeautifulSoup(html, 'html.parser')

# Imprimir la sección <head> del HTML
# print(soup.head)

# %% [markdown]
# ### **Extracción de Datos Meteorológicos por Ciudad**

# %%
# Encuentra todas las divisiones que contienen la información de la ciudad
city_divs = soup.find_all('div', class_='col-lg-12 p-2 m-0', style='background-color:lightblue;')

# Listas para almacenar los datos antes de crear el DataFrame
cities = []
days = []
temperature_highs = []
temperature_lows = []
descriptions = []

# %% [markdown]
# **Captura Eficiente de Datos Meteorológicos por Ciudad**
#
# En este paso, iteramos sobre las divisiones de la ciudad, extraemos la información necesaria y la almacenamos en listas.

# %%
# Listas para almacenar la información
cities = []
days = []
temperature_highs = []
temperature_lows = []
descriptions = []

for city_div in city_divs:
    # Extrae el nombre de la ciudad
    city_name_elem = city_div.find('span', class_='nameCity')
    if city_name_elem:
        city_name = city_name_elem.text.strip()

        # Encuentra el contenedor de información del clima para la ciudad actual
        td_element = city_div.find_next('td')

        try:
            # Extrae la información del clima para cada día
            for day_info in td_element.find_all('div', class_='row m-3', recursive=False):
                day = day_info.find('div', class_='col-sm-3').text.strip()
                temperature_high = day_info.find('div', class_='col-sm-1 text-danger').strong.text.strip()
                temperature_low = day_info.find('div', class_='col-sm-1 text-primary').strong.text.strip()
                description = day_info.find('div', class_='col-sm-6').text.strip()

                # Almacena la información en las listas
                cities.append(city_name)
                days.append(day)
                temperature_highs.append(temperature_high)
                temperature_lows.append(temperature_low)
                descriptions.append(description)

        except AttributeError as e:
            # Almacena información de error en listas
            cities.append(city_name)
            days.append("Error")
            temperature_highs.append("Error")
            temperature_lows.append("Error")
            descriptions.append("Error")

# Imprime las listas después de la iteración
print("Cities:", cities)
print("Days:", days)
print("Temperature Highs:", temperature_highs)
print("Temperature Lows:", temperature_lows)
print("Descriptions:", descriptions)
# Out:
# Cities: ['BAGUA GRANDE - AMAZONAS', 'BAGUA GRANDE - AMAZONAS', 'BAGUA GRANDE - AMAZONAS', 'BAGUA GRANDE - AMAZONAS', 'BAGUA GRANDE - AMAZONAS', 'CHACHAPOYAS - AMAZONAS', 'CHACHAPOYAS - AMAZONAS', 'CHACHAPOYAS - AMAZONAS', 'CHACHAPOYAS - AMAZONAS', 'CHACHAPOYAS - AMAZONAS', 'CHIRIACO - AMAZONAS', 'CHIRIACO - AMAZONAS', 'CHIRIACO - AMAZONAS', 'CHIRIACO - AMAZONAS', 'CHIRIACO - AMAZONAS', 'PEDRO RUIZ - AMAZONAS', 'PEDRO RUIZ - AMAZONAS', 'PEDRO RUIZ - AMAZONAS', 'PEDRO RUIZ - AMAZONAS', 'PEDRO RUIZ - AMAZONAS', 'SANTA MARIA DE NIEVA - AMAZONAS', 'SANTA MARIA DE NIEVA - AMAZONAS', 'SANTA MARIA DE NIEVA - AMAZONAS', 'SANTA MARIA DE NIEVA - AMAZONAS', 'SANTA MARIA DE NIEVA - AMAZONAS', 'CABANA - ANCASH', 'CABANA - ANCASH', 'CABANA - ANCASH', 'CABANA - ANCASH', 'CABANA - ANCASH', 'CASMA - ANCASH', 'CASMA - ANCASH', 'CASMA - ANCASH', 'CASMA - ANCASH', 'CASMA - ANCASH', 'CHAVIN - ANCASH', 'CHAVIN - ANCASH', 'CHAVIN - ANCASH', 'CHAVIN - ANCASH', 'CHAVIN - ANCASH', 'CHIMBOTE - ANCASH', 'CHIMBOTE - ANCASH', 'CHIMBOTE - ANCASH', 'CHIMBOTE - ANCASH', 'CHIMBOTE - ANCASH', 'CHIQUIÁN - ANCASH', 'CHIQUIÁN - ANCASH', 'CHIQUIÁN - ANCASH', 'CHIQUIÁN - ANCASH', 'CHIQUIÁN - ANCASH', 'HUARAZ - ANCASH', 'HUARAZ - ANCASH', 'HUARAZ - ANCASH', 'HUARAZ - ANCASH', 'HUARAZ - ANCASH', 'HUARMEY - ANCASH', 'HUARMEY - ANCASH', 'HUARMEY - ANCASH', 'HUARMEY - ANCASH', 'HUARMEY - ANCASH', 'POMABAMBA - ANCASH', 'POMABAMBA - ANCASH', 'POMABAMBA - ANCASH', 'POMABAMBA - ANCASH', 'POMABAMBA - ANCASH', 'RECUAY - ANCASH', 'RECUAY - ANCASH', 'RECUAY - ANCASH', 'RECUAY - ANCASH', 'RECUAY - ANCASH', 'SIHUAS - ANCASH', 'SIHUAS - ANCASH', 'SIHUAS - ANCASH', 'SIHUAS - ANCASH', 'SIHUAS - ANCASH', 'YUNGAY - ANCASH', 'YUNGAY - ANCASH', 'YUNGAY - ANCASH', 'YUNGAY - ANCASH', 'YUNGAY - ANCASH', 'ABANCAY - APURIMAC', 'ABANCAY - APURIMAC', 'ABANCAY - APURIMAC', 'ABANCAY - APURIMAC', 'ABANCAY - APURIMAC', 'ANDAHUAYLAS - APURIMAC', 'ANDAHUAYLAS - APURIMAC', 'ANDAHUAYLAS - APURIMAC', 'ANDAHUAYLAS - APURIMAC', 'ANDAHUAYLAS - APURIMAC', 'ANTABAMBA - APURIMAC', 'ANTABAMBA - APURIMAC', 'ANTABAMBA - APURIMAC', 'ANTABAMBA - APURIMAC', 'ANTABAMBA - APURIMAC', 'CHALHUANCA - APURIMAC', 'CHALHUANCA - APURIMAC', 'CHALHUANCA - APURIMAC', 'CHALHUANCA - APURIMAC', 'CHALHUANCA - APURIMAC', 'CURPAHUASI - APURIMAC', 'CURPAHUASI - APURIMAC', 'CURPAHUASI - APURIMAC', 'CURPAHUASI - APURIMAC', 'CURPAHUASI - APURIMAC', 'TAMBOBAMBA - APURIMAC', 'TAMBOBAMBA - APURIMAC', 'APLAO - AREQUIPA', 'APLAO - AREQUIPA', 'AREQUIPA - AREQUIPA', 'AREQUIPA - AREQUIPA', 'ATICO - AREQUIPA', 'ATICO - AREQUIPA', 'CABANACONDE - AREQUIPA', 'CABANACONDE - AREQUIPA', 'CAMANA - AREQUIPA', 'CAMANA - AREQUIPA', 'CARAVELI - AREQUIPA', 'CARAVELI - AREQUIPA', 'CAYLLOMA - AREQUIPA', 'CAYLLOMA - AREQUIPA', 'CHAPARRA - AREQUIPA', 'CHAPARRA - AREQUIPA', 'CHIGUATA - AREQUIPA', 'CHIGUATA - AREQUIPA', 'CHIVAY - AREQUIPA', 'CHIVAY - AREQUIPA', 'CHUQUIBAMBA - AREQUIPA', 'CHUQUIBAMBA - AREQUIPA', 'COTAHUASI - AREQUIPA', 'COTAHUASI - AREQUIPA', 'HUANCA - AREQUIPA', 'HUANCA - AREQUIPA', 'IMATA - AREQUIPA', 'IMATA - AREQUIPA', 'LA JOYA - AREQUIPA', 'LA JOYA - AREQUIPA', 'LOMAS - AREQUIPA', 'LOMAS - AREQUIPA', 'MAJES - AREQUIPA', 'MAJES - AREQUIPA', 'MOLLENDO - AREQUIPA', 'MOLLENDO - AREQUIPA', 'ORCOPAMPA - AREQUIPA', 'ORCOPAMPA - AREQUIPA', 'SIBAYO - AREQUIPA', 'SIBAYO - AREQUIPA', 'SIBAYO - AREQUIPA', 'SIBAYO - AREQUIPA', 'SIBAYO - AREQUIPA', 'ANCO - AYACUCHO', 'ANCO - AYACUCHO', 'ANCO - AYACUCHO', 'ANCO - AYACUCHO', 'ANCO - AYACUCHO', 'AYACUCHO - AYACUCHO', 'AYACUCHO - AYACUCHO', 'AYACUCHO - AYACUCHO', 'AYACUCHO - AYACUCHO', 'AYACUCHO - AYACUCHO', 'CORACORA - AYACUCHO', 'CORACORA - AYACUCHO', 'CORACORA - AYACUCHO', 'CORACORA - AYACUCHO', 'CORACORA - AYACUCHO', 'HUAC-HUAS - AYACUCHO', 'HUAC-HUAS - AYACUCHO', 'HUAC-HUAS - AYACUCHO', 'HUAC-HUAS - AYACUCHO', 'HUAC-HUAS - AYACUCHO', 'HUANCAPI - AYACUCHO', 'HUANCAPI - AYACUCHO', 'HUANCAPI - AYACUCHO', 'HUANCAPI - AYACUCHO', 'HUANCAPI - AYACUCHO', 'HUANTA - AYACUCHO', 'HUANTA - AYACUCHO', 'HUANTA - AYACUCHO ...
# Days: ['sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles, 17 de enero', 'sábado, 13 de enero', 'domingo, 14 de enero', 'lunes, 15 de enero', 'martes, 16 de enero', 'miércoles
.', 'Cielo nublado hacia la madrugada variando a cielo con nubes dispersas entre cielo despejado durante el día y cielo cubierto con lluvia ligera al atardecer.', 'Cielo nublado en las primeras horas de la mañana variando a cielo con nubes dispersas entre cielo despejado durante el día y cielo cubierto con lluvia ligera al atardecer.', 'Cielo nublado en las primeras horas de la mañana variando a cielo con nubes dispersas entre cielo despejado durante el día y cielo nublado con ráfagas de viento al atardecer.', 'Cielo cubierto en las primeras horas de la mañana variando a cielo con nubes dispersas entre cielo despejado hacia el mediodía y cielo nublado parcial al atardecer con ráfagas de viento.', 'Cielo nublado hacia la madrugada variando a cielo con nubes dispersas entre cielo despejado durante el día con tendencia a cielo nublado parcial al atardecer.', 'Cielo nublado parcial variando a cielo cubierto durante el día con lluvia y ráfagas de viento por la tarde.', 'Cielo nublado entre cielo nublado parcial por la mañana variando a cielo cubierto con lluvia y ráfagas de viento por la tarde.', 'Cielo nublado parcial entre cielo con nubes dispersas por la mañana variando a cielo cubierto con chubascos ligeros y ráfagas de viento por la tarde.', 'Cielo con nubes dispersas variando a cielo nublado parcial hacia el mediodía y cielo cubierto con tendenc ...

# %% [markdown]
# **Estructuración de Datos Meteorológicos en un DataFrame**

# %%
# Crea un DataFrame de pandas con los datos recopilados
df = pd.DataFrame({
    'City': cities,
    'Day': days,
    'Temperature High': temperature_highs,
    'Temperature Low': temperature_lows,
    'Description': descriptions
})

# Muestra el DataFrame
df
# Out:
#                             City                     Day Temperature High  \
# 0        BAGUA GRANDE - AMAZONAS     sábado, 13 de enero             19ºC
# 1        BAGUA GRANDE - AMAZONAS    domingo, 14 de enero             19ºC
# 2        BAGUA GRANDE - AMAZONAS      lunes, 15 de enero             19ºC
# 3        BAGUA GRANDE - AMAZONAS     martes, 16 de enero             19ºC
# 4        BAGUA GRANDE - AMAZONAS  miércoles, 17 de enero             19ºC
# ...                          ...                     ...              ...
# 1301  PUERTO ESPERANZA - UCAYALI    domingo, 14 de enero             31ºC
# 1302  PUERTO ESPERANZA - UCAYALI      lunes, 15 de enero             30ºC
# 1303  PUERTO ESPERANZA - UCAYALI     martes, 16 de enero             30ºC
# 1304  PUERTO ESPERANZA - UCAYALI  miércoles, 17 de enero             32ºC
# 1305     SAN ALEJANDRO - UCAYALI                   Error            Error
#
#      Temperature Low                                        Description
# 0               11ºC  Cielo nublado parcial hacia la madrugada a cie...
# 1               11ºC  Cielo nublado parcial a cielo nublado durante ...
# 2               11ºC  Cielo nublado parcial por la mañana a cielo nu...
# 3               11ºC  Cielo nublado con viento moderado por la mañan...
# 4               11ºC  Cielo nublado parcial entre cielo nublado dura...
# ...              ...                                                ...
# 1301            23ºC  Cielo nublado variando a cielo nublado parcial...
# 1302            23ºC  Cielo cubierto a cielo nublado durante el día ...
# 1303            23ºC  Cielo cubierto a cielo nublado durante el día ...
# 1304            23ºC  Cielo nublado variando a cielo nublado parcial...
# 1305           Error                                              Error
#
# [1306 rows x 5 columns]
